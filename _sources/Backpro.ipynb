# %% [markdown]
# # Menghitung Manual Backpropagation

# %% [markdown]
# Link excel Perhitungan Backpropagation
#
# [Backpropagation](https://docs.google.com/spreadsheets/d/1yMJ2pMZJCU_CLD3oovM3d46MyITX-ltdxCJ3_2EPLdE/edit?usp=sharing)
